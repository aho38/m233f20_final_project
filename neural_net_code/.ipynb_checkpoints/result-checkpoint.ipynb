# %%
import pickle
import numpy as np
import math
import matplotlib.pyplot as plt
import torch
#from test_data_gen import zero_isocontour
from IPython.display import Image

# %% [markdown]
# ## Circular Interface

# %%
x = pickle.load(open('./result/circular/exp3tensor_y.pkl', 'rb'))
y = pickle.load(open('./result/circular/exp3tensor_y_hat.pkl', 'rb'))
p = np.polyfit(x.squeeze(),y.squeeze(),1)

fig = plt.figure(figsize=(8,8))
plt.plot([x.min(), x.max()], [x.min()* p[0] + p[1], x.max() * p[0] + p[1]], 'r')
plt.plot(x,x, '--', c='k')
plt.scatter(x,y,s=5,c='b')
plt.legend(('fit', 'predicted=expected', 'data'))

# %% [markdown]
# ## Three Petal

# %%
x = pickle.load(open('./result/pedal/exp3tensor_y.pkl', 'rb'))
y = pickle.load(open('./result/pedal/exp3tensor_y_hat.pkl', 'rb'))
p = np.polyfit(x.squeeze(),y.squeeze(),1)

fig = plt.figure(figsize=(8,8))
plt.plot([x.min(), x.max()], [x.min()* p[0] + p[1], x.max() * p[0] + p[1]], 'r')
plt.plot(x,x, '--', c='k')
plt.scatter(x,y,s=5,c='b')
plt.legend(('fit', 'predicted=expected', 'data'))

# %% [markdown]
# ## Reinitialized three pedal

# %%
x = pickle.load(open('./result/pedal/exp3tensor_y.pkl', 'rb'))
y = pickle.load(open('./result/pedal/exp3tensor_y_hat.pkl', 'rb'))
p = np.polyfit(x.squeeze(),y.squeeze(),1)

fig = plt.figure(figsize=(8,8))
plt.plot([x.min(), x.max()], [x.min()* p[0] + p[1], x.max() * p[0] + p[1]], 'r')
plt.plot(x,x, '--', c='k')
plt.scatter(x,y,s=5,c='b')
plt.legend(('fit', 'predicted=expected', 'data'))

# %%
p = np.polyfit(x.squeeze(),y.squeeze(),1)

# %%
y.squeeze().size()
# Out:
# torch.Size([552])

# %%
p
# Out:
# array([1.02924556e+00, 3.09551687e-04])
